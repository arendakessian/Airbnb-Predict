# %% [markdown]
# **GOAL OF THIS NOTEBOOK**
# 1. Explore inherent feature selection methods given by Random Forest.
# 2. Determine semi-arbitrary cutoff of % important, reduce using those features
# 3. Begin introductory model fitting, with goal of minimizing MSE as compared to $R^2$.

# %%
import os
from zipfile import ZipFile

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
os.chdir("/Users/anhthyngo/ds-ga1001-master/")

# %%
cwd = os.getcwd()
datadir = '/'.join(cwd.split('/')) + '/data/'
listings = datadir + 'airbnb_clean.csv.zip'
print(listings)
# Out:
# /Users/anhthyngo/ds-ga1001-master/data/airbnb_clean.csv.zip

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
zf = ZipFile(listings) 
#data = pd.read_csv(zf.open("airbnb_clean.csv"), low_memory=False)
#data.drop('zipcode', axis = 1, inplace=True)
#data.head(5)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-7-41b7c5dc32c0> in <module>()
#       1 pd.set_option('display.max_rows', None)
#       2 pd.set_option('display.max_columns', None)
# ----> 3 zf = ZipFile(listings)
#       4 #data = pd.read_csv(zf.open("airbnb_clean.csv"), low_memory=False)
#       5 #data.drop('zipcode', axis = 1, inplace=True)
#
# ~/anaconda3/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1106         try:
#    1107             if mode == 'r':
# -> 1108                 self._RealGetContents()
#    1109             elif mode in ('w', 'x'):
#    1110                 # set the modified flag so central directory gets written
#
# ~/anaconda3/lib/python3.6/zipfile.py in _RealGetContents(self)
#    1173             raise BadZipFile("File is not a zip file")
#    1174         if not endrec:
# -> 1175             raise BadZipFile("File is not a zip file")
#    1176         if self.debug > 1:
#    1177             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
plt.hist(data['price'],bins=15)
# Out:
# (array([4.707e+04, 4.780e+02, 7.000e+01, 4.300e+01, 1.200e+01, 8.000e+00,
#         7.000e+00, 9.000e+00, 0.000e+00, 6.000e+00, 1.000e+00, 3.000e+00,
#         2.000e+00, 0.000e+00, 1.100e+01]),
#  array([    0.        ,   666.66666667,  1333.33333333,  2000.        ,
#          2666.66666667,  3333.33333333,  4000.        ,  4666.66666667,
#          5333.33333333,  6000.        ,  6666.66666667,  7333.33333333,
#          8000.        ,  8666.66666667,  9333.33333333, 10000.        ]),
#  <a list of 15 Patch objects>)

# %%
data["host_response_rate"].nunique()
# Out:
# 87

# %%
for col in data.columns:
    print(col,data[col].nunique())
# Out:
# host_response_rate 87
# host_listings_count 83
# host_total_listings_count 83
# latitude 18943
# longitude 14798
# accommodates 19
# bathrooms 16
# bedrooms 14
# beds 22
# guests_included 16
# minimum_nights 110
# maximum_nights 271
# minimum_minimum_nights 111
# maximum_minimum_nights 116
# minimum_maximum_nights 272
# maximum_maximum_nights 273
# minimum_nights_avg_ntm 572
# maximum_nights_avg_ntm 334
# availability_30 31
# availability_60 61
# availability_90 91
# availability_365 366
# number_of_reviews 399
# number_of_reviews_ltm 148
# review_scores_rating 54
# review_scores_accuracy 9
# review_scores_cleanliness 9
# review_scores_checkin 9
# review_scores_communication 9
# review_scores_location 9
# review_scores_value 9
# calculated_host_listings_count 48
# calculated_host_listings_count_entire_homes 38
# calculated_host_listings_count_private_rooms 26
# calculated_host_listings_count_shared_rooms 15
# reviews_per_month 961
# extra_people 101
# cleaning_fee 209
# security_deposit 220
# price 656
# host_is_superhost 2
# host_has_profile_pic 2
# host_identity_verified 2
# has_availability 1
# requires_license 1
# instant_bookable 2
# is_business_travel_ready 1
# require_guest_profile_picture 2
# require_guest_phone_verification 2
# host_verifications_ facebook 2
# host_verifications_ google 2
# host_verifications_ government_id 2
# host_verifications_ identity_manual 2
# host_verifications_ jumio 2
# host_verifications_ kba 2
# host_verifications_ manual_offline 2
# host_verifications_ manual_online 2
# host_verifications_ offline_government_id 2
# host_verifications_ phone 2
# host_verifications_ reviews 2
# host_verifications_ selfie 2
# host_verifications_ sent_id 2
# host_verifications_ sesame 2
# host_verifications_ sesame_offline 2
# host_verifications_ weibo 2
# host_verifications_ work_email 2
# host_verifications_ zhima_selfie 2
# host_verifications_email 2
# host_verifications_facebook 2
# host_verifications_google 2
# host_verifications_jumio 2
# host_verifications_offline_government_id 2
# host_verifications_phone 2
# host_verifications_reviews 2
# amenities_ toilet 2
# amenities_24-hour check-in 2
# amenities_Accessible-height bed 2
# amenities_Accessible-height toilet 2
# amenities_Air conditioning 2
# amenities_Air purifier 2
# amenities_BBQ grill 2
# amenities_Baby bath 2
# amenities_Baby monitor 2
# amenities_Babysitter recommendations 2
# amenities_Bathtub 2
# amenities_Bathtub with bath chair 2
# amenities_Beach essentials 2
# amenities_Beachfront 2
# amenities_Bed linens 2
# amenities_Breakfast 2
# amenities_Building staff 2
# amenities_Buzzer/wireless intercom 2
# amenities_Cable TV 2
# amenities_Carbon monoxide detector 2
# amenities_Cat(s) 2
# amenities_Ceiling hoist 2
# amenities_Changing table 2
# amenities_Children’s books and toys 2
# amenities_Children’s dinnerware 2
# amenities_Cleaning before checkout 2
# amenities_Coffee maker 2
# amenities_Cooking basics 2
# amenities_Crib 2
# amenities_Disabled parking spot 2
# amenities_Dishes and silverware 2
# amenities_Dishwasher 2
# amenities_Dog(s) 2
# amenities_Doorman 2
# amenities_Dryer 2
# amenities_EV charger 2
# amenities_Electric profiling bed 2
# amenities_Elevator 2
# amenities_Essentials 2
# amenities_Ethernet connection 2
# amenities_Extra pillows and blankets 2
# amenities_Extra space around bed 2
# amenities_Family/kid friendly 2
# amenities_Fire extinguisher 2
# amenities_Fireplace guards 2
# amenities_Firm mattress 2
# amenities_First aid kit 2
# amenities_Fixed grab bars for shower 2
# amenities_Fixed grab bars for toilet 2
# amenities_Flat path to guest entrance 2
# amenities_Free parking on premises 2
# amenities_Free street parking 2
# amenities_Full kitchen 2
# amenities_Game console 2
# amenities_Garden or backyard 2
# amenities_Ground floor access 2
# amenities_Gym 2
# amenities_Hair dryer 2
# amenities_Handheld shower head 2
# amenities_Hangers 2
# amenities_Heating 2
# amenities_High chair 2
# amenities_Host greets you 2
# amenities_Hot tub 2
# amenities_Hot water 2
# amenities_Hot water kettle 2
# amenities_Indoor fireplace 2
# amenities_Internet 2
# amenities_Iron 2
# amenities_Keypad 2
# amenities_Kitchen 2
# amenities_Kitchenette 2
# amenities_Lake access 2
# amenities_Laptop friendly workspace 2
# amenities_Lock on bedroom door 2
# amenities_Lockbox 2
# amenities_Long term stays allowed 2
# amenities_Luggage dropoff allowed 2
# amenities_Microwave 2
# amenities_Mobile hoist 2
# amenities_No stairs or steps to enter 2
# amenities_Other 2
# amenities_Other pet(s) 2
# amenities_Outlet covers 2
# amenities_Oven 2
# amenities_Pack ’n Play/travel crib 2
# amenities_Paid parking off premises 2
# amenities_Paid parking on premises 2
# amenities_Patio or balcony 2
# amenities_Pets allowed 2
# amenities_Pets live on this property 2
# amenities_Pocket wifi 2
# amenities_Pool 2
# amenities_Pool with pool hoist 2
# amenities_Private bathroom 2
# amenities_Private entrance 2
# amenities_Private living room 2
# amenities_Refrigerator 2
# amenities_Roll-in shower 2
# amenities_Room-darkening shades 2
# amenities_Safety card 2
# amenities_Self check-in 2
# amenities_Shampoo 2
# amenities_Shower chair 2
# amenities_Single level home 2
# amenities_Ski-in/Ski-out 2
# amenities_Smart lock 2
# amenities_Smoke detector 2
# amenities_Smoking allowed 2
# amenities_Stair gates 2
# amenities_Stove 2
# amenities_Suitable for events 2
# amenities_TV 2
# amenities_Table corner guards 2
# amenities_Washer 2
# amenities_Washer / Dryer 2
# amenities_Waterfront 2
# amenities_Well-lit path to entrance 2
# amenities_Wheelchair accessible 2
# amenities_Wide clearance to shower 2
# amenities_Wide doorway to guest bathroom 2
# amenities_Wide entrance 2
# amenities_Wide entrance for guests 2
# amenities_Wide entryway 2
# amenities_Wide hallways 2
# amenities_Wifi 2
# amenities_Window guards 2
# amenities_translation missing: en.hosting_amenity_49 2
# amenities_translation missing: en.hosting_amenity_50 2
# neighbourhood_group_cleansed_Bronx 2
# neighbourhood_group_cleansed_Brooklyn 2
# neighbourhood_group_cleansed_Manhattan 2
# neighbourhood_group_cleansed_Queens 2
# neighbourhood_group_cleansed_Staten Island 2
# property_type_Aparthotel 2
# property_type_Apartment 2
# property_type_Barn 2
# property_type_Bed and breakfast 2
# property_type_Boat 2
# property_type_Boutique hotel 2
# property_type_Bungalow 2
# property_type_Bus 2
# property_type_Cabin 2
# property_type_Camper/RV 2
# property_type_Casa particular (Cuba) 2
# property_type_Castle 2
# property_type_Cave 2
# property_type_Condominium 2
# property_type_Cottage 2
# property_type_Dome house 2
# property_type_Earth house 2
# property_type_Farm stay 2
# property_type_Guest suite 2
# property_type_Guesthouse 2
# property_type_Hostel 2
# property_type_Hotel 2
# property_type_House 2
# property_type_Houseboat 2
# property_type_Island 2
# property_type_Loft 2
# property_type_Nature lodge 2
# property_type_Other 2
# property_type_Resort 2
# property_type_Serviced apartment 2
# property_type_Tent 2
# property_type_Timeshare 2
# property_type_Tiny house 2
# property_type_Townhouse 2
# property_type_Villa 2
# property_type_Yurt 2
# room_type_Entire home/apt 2
# room_type_Hotel room 2
# room_type_Private room 2
# room_type_Shared room 2
# bed_type_Airbed 2
# bed_type_Couch 2
# bed_type_Futon 2
# bed_type_Pull-out Sofa 2
# bed_type_Real Bed 2
# cancellation_policy_flexible 2
# cancellation_policy_moderate 2
# cancellation_policy_strict 2
# cancellation_policy_strict_14_with_grace_period 2
# cancellation_policy_super_strict_30 2
# cancellation_policy_super_strict_60 2

# %%
columns = data.columns


data_no = []

for col in columns:
    if data[col].nunique() != 2:
        data_no.append([col,data[col].quantile(0.02),data[col].quantile(0.98)])
    else:
        data_no.append([col,data[col].min(),data[col].max()])
df = pd.DataFrame(data_no, columns = ['column','5','95']) 
df.head()
# Out:
#                       column          5          95
# 0         host_response_rate   0.330000    1.000000
# 1        host_listings_count   0.000000  168.000000
# 2  host_total_listings_count   0.000000  168.000000
# 3                   latitude  40.619551   40.851770
# 4                  longitude -74.011319  -73.806359

# %%
for index, row in df.iterrows():
   
    data = data[(data[df['column'][index]]>= df['5'][index]) & (data[df['column'][index]] <= df['95'][index])]
    print(data.shape)
# Out:
# (31072, 259)
# (30132, 259)
# (30132, 259)
# (28676, 259)
# (27525, 259)
# (26973, 259)
# (26480, 259)
# (26299, 259)
# (26170, 259)
# (25827, 259)
# (25344, 259)
# (25100, 259)
# (25100, 259)
# (25015, 259)
# (24996, 259)
# (24996, 259)
# (24996, 259)
# (24996, 259)
# (24996, 259)
# (24996, 259)
# (24996, 259)
# (24638, 259)
# (23833, 259)
# (23332, 259)
# (20110, 259)
# (20056, 259)
# (20028, 259)
# (19932, 259)
# (19867, 259)
# (19766, 259)
# (19723, 259)
# (19668, 259)
# (19590, 259)
# (19247, 259)
# (18902, 259)
# (18623, 259)
# (18221, 259)
# (16206, 259)
# (13468, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)
# (13270, 259)

# %%
plt.hist(data['price'],bins=15)
# Out:
# (array([2567., 2766., 2623., 1712., 1114.,  931.,  579.,  236.,  301.,
#          134.,   59.,   97.,   72.,   12.,   67.]),
#  array([ 34. ,  66.4,  98.8, 131.2, 163.6, 196. , 228.4, 260.8, 293.2,
#         325.6, 358. , 390.4, 422.8, 455.2, 487.6, 520. ]),
#  <a list of 15 Patch objects>)

# %%
X = data.drop('price',axis=1)
Y = np.log(data.pop('price'))

# %%
print(X.shape)
print(X)
# Out:
# (13270, 258)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
nan_cols = [i for i in X.columns if X[i].isnull().any()]
nan_cols
# Out:
# []

# %%
'''
Some columns have NANs. To move forward with feature selection, these will be imputed. 
When we get to the pipeline implementation, we can be more careful about this. 
For now, as in line with the rest of our analysis, we'll impute with median. 

We will separately impute our training and testing split (block below)
'''
# Out:
# "\nSome columns have NANs. To move forward with feature selection, these will be imputed. \nWhen we get to the pipeline implementation, we can be more careful about this. \nFor now, as in line with the rest of our analysis, we'll impute with median. \n\nWe will separately impute our training and testing split (block below)\n"

# %%
'''
PART 1 -- INHERENT FEATURE SELECTION OF RANDOM FOREST
Essentially here we're just creating some notion of how a Regression RF does in terms of mean accuracy with or without 
certain features.
While it's worth nothing there is zero model optimization going on here, there's still information to be gained. 
'''
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,Y,test_size=.2,random_state=42)

# %%
for col in nan_cols:
    Xtrain[col].fillna(Xtrain[col].median(),inplace=True)
    Xtest[col].fillna(Xtest[col].median(),inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor()
model = regr.fit(Xtrain,Ytrain)
# Out:
# /Users/anhthyngo/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
'''
Now that the model has been fit, we can look at what features it deems to be important. 
In addition, it's worth knowing the ratio of important variables to overall features. 
'''
# Out:
# "\nNow that the model has been fit, we can look at what features it deems to be important. \nIn addition, it's worth knowing the ratio of important variables to overall features. \n"

# %%
feature_importances = model.feature_importances_
sorted_indices = np.argsort(feature_importances)

# %%
'''
The following block will produce a sorted list of the columns with a feature importance > .005,
as well as some additional information (discussed above) that is worth knowing.
'''
# Out:
# '\nThe following block will produce a sorted list of the columns with a feature importance > .005,\nas well as some additional information (discussed above) that is worth knowing.\n'

# %%
total = 0 
reduced_features = []
for i in range(len(sorted_indices)):
    feature , importance = list(X.columns)[sorted_indices[-i]], feature_importances[sorted_indices[-i]]
    if(importance > .005):
        reduced_features.append(feature)
        total+=importance
        print(feature,importance)
print("-------------------------------------------------------------------------")
print(len(feature_importances[feature_importances>=.005]),"variables account for",round(total*100,2),"% of the feature importance.")
print("\n")
print("Can account for",round(total*100,2),"% of the feature importance deemed by the model with",round((len(feature_importances[feature_importances>=.005])/X.shape[1])*100,2),"% \n of the original number of features")
print("-------------------------------------------------------------------------")
# Out:
# room_type_Private room 0.3149919508558875
# longitude 0.07576303186136658
# neighbourhood_group_cleansed_Manhattan 0.06523369555368798
# bedrooms 0.06341560775397505
# latitude 0.0510470106790349
# bathrooms 0.03656199275571529
# cleaning_fee 0.03626272357071197
# accommodates 0.02782499665600313
# availability_365 0.016540750840723407
# availability_30 0.015050521801255786
# reviews_per_month 0.013337834813950506
# availability_90 0.012888630636825308
# availability_60 0.01234161137160216
# security_deposit 0.010919255963032927
# review_scores_rating 0.010393143190906564
# number_of_reviews 0.00984343418370269
# minimum_minimum_nights 0.008557473569136696
# maximum_minimum_nights 0.008504860229321506
# guests_included 0.008404760939263003
# extra_people 0.00811945329765706
# minimum_nights_avg_ntm 0.007768808697361097
# minimum_nights 0.007758186392970078
# number_of_reviews_ltm 0.007269396666036029
# -------------------------------------------------------------------------
# 23 variables account for 82.88 % of the feature importance.
#
#
# Can account for 82.88 % of the feature importance deemed by the model with 8.91 %
#  of the original number of features
# -------------------------------------------------------------------------

# %%
'''
CONCLUSION
29 variables account for 92% of feature importance seems to be a good tradeoff between
complexity and feature relevance. We can move forward from here
'''
# Out:
# '\nCONCLUSION\n29 variables account for 92% of feature importance seems to be a good tradeoff between\ncomplexity and feature relevance. We can move forward from here\n'

# %%
'''
PART 2a-- CREATING REDUCED DATASET
'''
# Out:
# '\nPART 2a-- CREATING REDUCED DATASET\n'

# %%
'''
Re-reading in data so we don't have any carryover from modifications in step1
'''

#data = pd.read_csv(zf.open("airbnb_no_impute_20191202.csv"), low_memory=False)
#reduced_features.append('price')
data =  data[[c for c in data.columns if c in reduced_features]]
data['price'] = Y
data.head()
# Out:
#     latitude  longitude  accommodates  bathrooms  bedrooms  guests_included  \
# 5   40.72764  -73.97949             2        1.0       1.0                2
# 7   40.80316  -73.96545             2        1.0       1.0                1
# 9   40.66829  -73.98779             2        1.0       1.0                1
# 10  40.79826  -73.96113             1        1.0       1.0                1
# 14  40.67592  -73.94694             4        1.0       1.0                3
#
#     minimum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 5               30                      30                      30
# 7                5                       5                       5
# 9                4                       4                       4
# 10               2                       2                       2
# 14               3                       3                       3
#
#     minimum_nights_avg_ntm  availability_30  availability_60  availability_90  \
# 5                     30.0               12               42               72
# 7                      5.0                1                1                1
# 9                      4.0                6               29               59
# 10                     2.0                3               24               54
# 14                     3.0                0                8               34
#
#     availability_365  number_of_reviews  number_of_reviews_ltm  \
# 5                347                 94                      0
# 7                 40                 54                     12
# 9                332                171                     14
# 10               329                116                     25
# 14                34                 62                     53
#
#     review_scores_rating  reviews_per_month  extra_people  cleaning_fee  \
# 5                   95.0               0.73          15.0          75.0
# 7                   93.0               0.43           0.0          75.0
# 9                   94.0               1.35          22.0          67.0
# 10                  92.0               0.92          40.0          80.0
# 14                  96.0               4.39          50.0          70.0
#
#     security_deposit  neighbourhood_group_cleansed_Manhattan  \
# 5              500.0                                       1
# 7              450.0                                       1
# 9              200.0                                       0
# 10             200.0                                       1
# 14             500.0                                       0
#
#     room_type_Private room  price
# 5                        0  116.0
# 7                        0  135.0
# 9                        1   89.0
# 10                       1   85.0
# 14                       0   99.0

# %%
plt.hist(data['price'],bins=15)
# Out:
# (array([2567., 2766., 2623., 1712., 1114.,  931.,  579.,  236.,  301.,
#          134.,   59.,   97.,   72.,   12.,   67.]),
#  array([ 34. ,  66.4,  98.8, 131.2, 163.6, 196. , 228.4, 260.8, 293.2,
#         325.6, 358. , 390.4, 422.8, 455.2, 487.6, 520. ]),
#  <a list of 15 Patch objects>)

# %%
data.shape
# Out:
# (13049, 24)

# %%
'''
If you want to read this csv onto your local system and run some models locally, just run this 
block with a specified path.

NOTE: outside of feature reduction, there are no differences between this and the original dataset. 
the 5 columns will still have NANs, there is no train-test splitting going on, etc. 
'''

data.to_csv(os.getcwd()+'/data/airbnb_feature_selection.csv.gz', index=False, compression='gzip')

# %%
'''
PART 2b -- MODELING

Now we can start with some modeling to see what can produce the lowest MSE. 
OPTIONS FOR MODELING: 
Linear Regression - OLS (cross validate)
Linear Regression - Lasso (cross validate, parameter grid search)
Linear Regression - Ridge (cross validate, parameter grid search)
Random Forest - (hyperparameter grid search)
XGBoost - (hyperparameter grid search)
'''

# %%
data.head()
# Out:
#     zipcode  latitude  longitude  accommodates  bathrooms  bedrooms  \
# 5     10009  40.72764  -73.97949             2        1.0       1.0
# 7     10025  40.80316  -73.96545             2        1.0       1.0
# 9     11215  40.66829  -73.98779             2        1.0       1.0
# 10    10025  40.79826  -73.96113             1        1.0       1.0
# 14    11216  40.67592  -73.94694             4        1.0       1.0
#
#     guests_included  minimum_nights  minimum_minimum_nights  \
# 5                 2              30                      30
# 7                 1               5                       5
# 9                 1               4                       4
# 10                1               2                       2
# 14                3               3                       3
#
#     maximum_minimum_nights  minimum_nights_avg_ntm  availability_30  \
# 5                       30                    30.0               12
# 7                        5                     5.0                1
# 9                        4                     4.0                6
# 10                       2                     2.0                3
# 14                       3                     3.0                0
#
#     availability_60  availability_90  availability_365  number_of_reviews  \
# 5                42               72               347                 94
# 7                 1                1                40                 54
# 9                29               59               332                171
# 10               24               54               329                116
# 14                8               34                34                 62
#
#     number_of_reviews_ltm  review_scores_rating  reviews_per_month  \
# 5                       0                  95.0               0.73
# 7                      12                  93.0               0.43
# 9                      14                  94.0               1.35
# 10                     25                  92.0               0.92
# 14                     53                  96.0               4.39
#
#     extra_people  cleaning_fee  security_deposit  room_type_Private room  \
# 5           15.0          75.0             500.0                       0
# 7            0.0          75.0             450.0                       0
# 9           22.0          67.0             200.0                       1
# 10          40.0          80.0             200.0                       1
# 14          50.0          70.0             500.0                       0
#
#     price
# 5   116.0
# 7   135.0
# 9    89.0
# 10   85.0
# 14   99.0
